# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/georgearredondo/Downloads/DOGE-USD.csv')

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  2016-02-08  0.000285  0.000299  0.000283  0.000287   0.000287  189115.0
# 1  2016-02-09  0.000287  0.000296  0.000286  0.000292   0.000292  126218.0
# 2  2016-02-10  0.000291  0.000304  0.000290  0.000298   0.000298  266304.0
# 3  2016-02-11  0.000297  0.000303  0.000280  0.000290   0.000290  343798.0
# 4  2016-02-12  0.000293  0.000301  0.000284  0.000301   0.000301  435781.0

# %%
df.shape
# Out:
# (1828, 7)

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1828, step=1)

# %%
# Setting my index as the date column and making the date a dtype of datetime instead of an object
df = pd.read_csv('/Users/georgearredondo/Downloads/DOGE-USD.csv', index_col=0, parse_dates=True)

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2016-02-08  0.000285  0.000299  0.000283  0.000287   0.000287  189115.0
# 2016-02-09  0.000287  0.000296  0.000286  0.000292   0.000292  126218.0
# 2016-02-10  0.000291  0.000304  0.000290  0.000298   0.000298  266304.0
# 2016-02-11  0.000297  0.000303  0.000280  0.000290   0.000290  343798.0
# 2016-02-12  0.000293  0.000301  0.000284  0.000301   0.000301  435781.0

# %%
df.index
# Out:
# DatetimeIndex(['2016-02-08', '2016-02-09', '2016-02-10', '2016-02-11',
#                '2016-02-12', '2016-02-13', '2016-02-14', '2016-02-15',
#                '2016-02-16', '2016-02-17',
#                ...
#                '2021-01-30', '2021-01-31', '2021-02-01', '2021-02-02',
#                '2021-02-03', '2021-02-04', '2021-02-05', '2021-02-06',
#                '2021-02-07', '2021-02-08'],
#               dtype='datetime64[ns]', name='Date', length=1828, freq=None)

# %%
# Looking at data from the 30th till today (02-08) 
df.loc['2021-01-30':]
# Out:
#                 Open      High       Low     Close  Adj Close        Volume
# Date
# 2021-01-30  0.046803  0.049901  0.022488  0.028176   0.028176  8.735577e+09
# 2021-01-31  0.028191  0.045289  0.027102  0.037196   0.037196  8.548998e+09
# 2021-02-01  0.037054  0.043250  0.033367  0.034875   0.034875  6.319224e+09
# 2021-02-02  0.034910  0.034926  0.029195  0.031520   0.031520  3.090897e+09
# 2021-02-03  0.031493  0.039105  0.031146  0.037120   0.037120  3.146857e+09
# 2021-02-04  0.037226  0.057869  0.035945  0.053289   0.053289  1.304084e+10
# 2021-02-05  0.053043  0.053740  0.043540  0.046935   0.046935  6.136160e+09
# 2021-02-06  0.046931  0.058308  0.044904  0.057595   0.057595  5.946101e+09
# 2021-02-07  0.057502  0.084357  0.054239  0.078782   0.078782  1.426102e+10
# 2021-02-08  0.071006  0.084945  0.065339  0.080928   0.080928  1.512395e+10

# %%
# Everthing from 2016 to 01-30-2021
df.loc[:'2021-01-30']
# Out:
#                 Open      High       Low     Close  Adj Close        Volume
# Date
# 2016-02-08  0.000285  0.000299  0.000283  0.000287   0.000287  1.891150e+05
# 2016-02-09  0.000287  0.000296  0.000286  0.000292   0.000292  1.262180e+05
# 2016-02-10  0.000291  0.000304  0.000290  0.000298   0.000298  2.663040e+05
# 2016-02-11  0.000297  0.000303  0.000280  0.000290   0.000290  3.437980e+05
# 2016-02-12  0.000293  0.000301  0.000284  0.000301   0.000301  4.357810e+05
# ...              ...       ...       ...       ...        ...           ...
# 2021-01-26  0.008382  0.008456  0.008022  0.008255   0.008255  1.611737e+08
# 2021-01-27  0.008255  0.008259  0.007294  0.007482   0.007482  2.047972e+08
# 2021-01-28  0.007481  0.013826  0.007351  0.012555   0.012555  2.125006e+09
# 2021-01-29  0.043734  0.077973  0.032341  0.047162   0.047162  2.540331e+10
# 2021-01-30  0.046803  0.049901  0.022488  0.028176   0.028176  8.735577e+09
#
# [1819 rows x 6 columns]

# %%
# Shows the last day in the data set
df.iloc[-1]
# Out:
# Open         7.100600e-02
# High         8.494500e-02
# Low          6.533900e-02
# Close        8.092800e-02
# Adj Close    8.092800e-02
# Volume       1.512395e+10
# Name: 2021-02-08 00:00:00, dtype: float64

# %%
df['Close']
# Out:
# Date
# 2016-02-08    0.000287
# 2016-02-09    0.000292
# 2016-02-10    0.000298
# 2016-02-11    0.000290
# 2016-02-12    0.000301
#                 ...
# 2021-02-04    0.053289
# 2021-02-05    0.046935
# 2021-02-06    0.057595
# 2021-02-07    0.078782
# 2021-02-08    0.080928
# Name: Close, Length: 1828, dtype: float64

# %%
# Series of close data points
type(df['Close'])
# Out:
# pandas.core.series.Series

# %%
daily_change = df['Open'] - df['Close']
daily_change
# Out:
# Date
# 2016-02-08   -0.000002
# 2016-02-09   -0.000005
# 2016-02-10   -0.000007
# 2016-02-11    0.000007
# 2016-02-12   -0.000008
#                 ...
# 2021-02-04   -0.016063
# 2021-02-05    0.006108
# 2021-02-06   -0.010664
# 2021-02-07   -0.021280
# 2021-02-08   -0.009922
# Length: 1828, dtype: float64

# %%
daily_pct_change = (df['Close'] - df['Open'])/ df['Open'] * 100
daily_pct_change
# Out:
# Date
# 2016-02-08     0.701754
# 2016-02-09     1.742160
# 2016-02-10     2.405498
# 2016-02-11    -2.356902
# 2016-02-12     2.730375
#                 ...
# 2021-02-04    43.149949
# 2021-02-05   -11.515186
# 2021-02-06    22.722721
# 2021-02-07    37.007408
# 2021-02-08    13.973467
# Length: 1828, dtype: float64

# %%
df['daily_change'] = df['Open'] - df['Close']

# %%
df['daily_pct_change'] = (df['Close'] - df['Open'])/ df['Open'] * 100

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2016-02-08  0.000285  0.000299  0.000283  0.000287   0.000287  189115.0
# 2016-02-09  0.000287  0.000296  0.000286  0.000292   0.000292  126218.0
# 2016-02-10  0.000291  0.000304  0.000290  0.000298   0.000298  266304.0
# 2016-02-11  0.000297  0.000303  0.000280  0.000290   0.000290  343798.0
# 2016-02-12  0.000293  0.000301  0.000284  0.000301   0.000301  435781.0
#
#             daily_change  daily_pct_change
# Date
# 2016-02-08     -0.000002          0.701754
# 2016-02-09     -0.000005          1.742160
# 2016-02-10     -0.000007          2.405498
# 2016-02-11      0.000007         -2.356902
# 2016-02-12     -0.000008          2.730375

# %%
#How much gained if purchased 
normalized = df['Close']/df['Close'].iloc[0]
normalized
# Out:
# Date
# 2016-02-08      1.000000
# 2016-02-09      1.017422
# 2016-02-10      1.038328
# 2016-02-11      1.010453
# 2016-02-12      1.048780
#                  ...
# 2021-02-04    185.675958
# 2021-02-05    163.536585
# 2021-02-06    200.679443
# 2021-02-07    274.501742
# 2021-02-08    281.979094
# Name: Close, Length: 1828, dtype: float64

# %%
df['normalized'] = df['Close']/df['Close'].iloc[0]
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2016-02-08  0.000285  0.000299  0.000283  0.000287   0.000287  189115.0
# 2016-02-09  0.000287  0.000296  0.000286  0.000292   0.000292  126218.0
# 2016-02-10  0.000291  0.000304  0.000290  0.000298   0.000298  266304.0
# 2016-02-11  0.000297  0.000303  0.000280  0.000290   0.000290  343798.0
# 2016-02-12  0.000293  0.000301  0.000284  0.000301   0.000301  435781.0
#
#             daily_change  daily_pct_change  normalized
# Date
# 2016-02-08     -0.000002          0.701754    1.000000
# 2016-02-09     -0.000005          1.742160    1.017422
# 2016-02-10     -0.000007          2.405498    1.038328
# 2016-02-11      0.000007         -2.356902    1.010453
# 2016-02-12     -0.000008          2.730375    1.048780

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
df['daily_pct_change'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fig2, ax1 = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df['daily_pct_change'].plot(ax=ax1)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fig3, ax2 = plt.subplots(2,2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df['Open'].plot(ax=ax2[0,0])
df['High'].plot(ax=ax2[0,1])
df['Low'].plot(ax=ax2[1,0])
df['Close'].plot(ax=ax2[1,1])
plt.tight_layout()
plt.suptitle('Open, High, Low, Close')
# Out:
# Text(0.5, 0.98, 'Open, High, Low, Close')

# %%
fig4, ax3 = plt.subplots()
df.loc[:'2021-01-31', "Volume"].plot.bar(ax=ax3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
fig2.savefig('plot.png')

# %%
df
# Out:
#                 Open      High       Low     Close  Adj Close        Volume  \
# Date
# 2016-02-08  0.000285  0.000299  0.000283  0.000287   0.000287  1.891150e+05
# 2016-02-09  0.000287  0.000296  0.000286  0.000292   0.000292  1.262180e+05
# 2016-02-10  0.000291  0.000304  0.000290  0.000298   0.000298  2.663040e+05
# 2016-02-11  0.000297  0.000303  0.000280  0.000290   0.000290  3.437980e+05
# 2016-02-12  0.000293  0.000301  0.000284  0.000301   0.000301  4.357810e+05
# ...              ...       ...       ...       ...        ...           ...
# 2021-02-04  0.037226  0.057869  0.035945  0.053289   0.053289  1.304084e+10
# 2021-02-05  0.053043  0.053740  0.043540  0.046935   0.046935  6.136160e+09
# 2021-02-06  0.046931  0.058308  0.044904  0.057595   0.057595  5.946101e+09
# 2021-02-07  0.057502  0.084357  0.054239  0.078782   0.078782  1.426102e+10
# 2021-02-08  0.071006  0.084945  0.065339  0.080928   0.080928  1.512395e+10
#
# ...

# %%
df['Close'].min()
# Out:
# 0.000197

# %%
df.min()
# Out:
# Open                    0.000197
# High                    0.000205
# Low                     0.000195
# Close                   0.000197
# Adj Close               0.000197
# Volume              46799.000000
# daily_change           -0.021280
# daily_pct_change      -39.798731
# normalized              0.686411
# dtype: float64

# %%
# This is the index of where the minimum was located
df['Close'].argmin()
# Out:
# 376

# %%
# Looking at all the variables on this particular day
df.iloc[376]
# Out:
# Open                     0.000209
# High                     0.000210
# Low                      0.000196
# Close                    0.000197
# Adj Close                0.000197
# Volume              158688.000000
# daily_change             0.000012
# daily_pct_change        -5.741627
# normalized               0.686411
# Name: 2017-02-18 00:00:00, dtype: float64

# %%
# Looking at a range of days
df.iloc[370:385]
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2017-02-12  0.000210  0.000211  0.000205  0.000208   0.000208   96618.0
# 2017-02-13  0.000210  0.000211  0.000204  0.000208   0.000208  128635.0
# 2017-02-14  0.000208  0.000213  0.000205  0.000209   0.000209  129514.0
# 2017-02-15  0.000208  0.000212  0.000203  0.000209   0.000209  154245.0
# 2017-02-16  0.000209  0.000212  0.000202  0.000207   0.000207  135279.0
# 2017-02-17  0.000207  0.000213  0.000202  0.000209   0.000209  153199.0
# 2017-02-18  0.000209  0.000210  0.000196  0.000197   0.000197  158688.0
# 2017-02-19  0.000197  0.000210  0.000196  0.000208   0.000208   74856.0
# 2017-02-20  0.000208  0.000209  0.000204  0.000207   0.000207   89141.0
# 2017-02-21  0.000210  0.000211  0.000202  0.000208   0.000208  102673.0
# 2017-02-22  0.000208  0.000210  0.000197  0.000202   0.000202  108610.0
# 2017-02-23  0.000202  0.000208  0.000198  0.000208   0.000208  110405.0
# ...

# %%
df['Close'].argmax()
# Out:
# 1827

# %%
# So the last day when i got this data set had the highest close
df.iloc[1827:]
# Out:
#                 Open      High       Low     Close  Adj Close        Volume  \
# Date
# 2021-02-08  0.071006  0.084945  0.065339  0.080928   0.080928  1.512395e+10
#
#             daily_change  daily_pct_change  normalized
# Date
# 2021-02-08     -0.009922         13.973467  281.979094

# %%
df["Close"].mean()
# Out:
# 0.002724736842105264

# %%
df.drop(['Low','Adj Close'], axis=1)
# Out:
#                 Open      High     Close        Volume  daily_change  \
# Date
# 2016-02-08  0.000285  0.000299  0.000287  1.891150e+05     -0.000002
# 2016-02-09  0.000287  0.000296  0.000292  1.262180e+05     -0.000005
# 2016-02-10  0.000291  0.000304  0.000298  2.663040e+05     -0.000007
# 2016-02-11  0.000297  0.000303  0.000290  3.437980e+05      0.000007
# 2016-02-12  0.000293  0.000301  0.000301  4.357810e+05     -0.000008
# ...              ...       ...       ...           ...           ...
# 2021-02-04  0.037226  0.057869  0.053289  1.304084e+10     -0.016063
# 2021-02-05  0.053043  0.053740  0.046935  6.136160e+09      0.006108
# 2021-02-06  0.046931  0.058308  0.057595  5.946101e+09     -0.010664
# 2021-02-07  0.057502  0.084357  0.078782  1.426102e+10     -0.021280
# 2021-02-08  0.071006  0.084945  0.080928  1.512395e+10     -0.009922
#
#             daily_pct_change  normalized
# Date
# 2016-02-08          0.701754    1.000000
# 2016-02-09          1.742160    1.017422
# ...

# %%
fig, ax = plt.subplots()
df['Close'].plot(ax=ax)
ax.set_title('DOGE')
ax.set_ylabel('Price')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Price')

# %%
fig, ax = plt.subplots(2,2)
df['Open'].plot(ax=ax[0,0], title="Open")
df['High'].plot(ax=ax[0,1], title="High")
df['Low'].plot(ax=ax[1,0], title="Low")
df['Close'].plot(ax=ax[1,1], title="Close")
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax = plt.subplots()
df["Volume"].loc['2021-01-15':'2021-01-31'].plot.barh(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:ylabel='Date'>
