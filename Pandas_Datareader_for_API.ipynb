# %%
import pandas_datareader as pdr

# %%
import datetime as dt

# %%
ticker = 'AAPL'
start = dt.datetime(2020,1,1)

# %%
df = pdr.get_data_yahoo(ticker,start)

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  74.333511
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.610840
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  74.197395
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.848442
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  75.036385

# %%
# Index already set as a datetime
df.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-02-09', '2021-02-10', '2021-02-11', '2021-02-12',
#                '2021-02-16', '2021-02-17', '2021-02-18', '2021-02-19',
#                '2021-02-22', '2021-02-23'],
#               dtype='datetime64[ns]', name='Date', length=288, freq=None)

# %%
# All data is floats
df.dtypes
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %%
# Data up to date and shows data up till today
df.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-02-17  132.220001  129.470001  131.250000  130.839996   97918500.0
# 2021-02-18  130.000000  127.410004  129.199997  129.710007   96648100.0
# 2021-02-19  130.710007  128.800003  130.240005  129.869995   87525900.0
# 2021-02-22  129.720001  125.599998  128.009995  126.000000  103607600.0
# 2021-02-23  124.120003  118.389999  123.760002  123.099899   73240258.0
#
#              Adj Close
# Date
# 2021-02-17  130.839996
# 2021-02-18  129.710007
# 2021-02-19  129.869995
# 2021-02-22  126.000000
# 2021-02-23  123.099899

# %%
# Setting an endtime to get a range of data
end = dt.datetime(2020,12,31)
df2 = pdr.get_data_yahoo(ticker, start, end)

# %%
df2.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  74.333511
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.610840
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  74.197395
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.848442
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  75.036385

# %%
df2.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-12-24  133.460007  131.100006  131.320007  131.970001   54930100.0
# 2020-12-28  137.339996  133.509995  133.990005  136.690002  124486200.0
# 2020-12-29  138.789993  134.339996  138.050003  134.869995  121047300.0
# 2020-12-30  135.990005  133.399994  135.580002  133.720001   96452100.0
# 2020-12-31  134.740005  131.720001  134.080002  132.690002   99116600.0
#
#              Adj Close
# Date
# 2020-12-24  131.773087
# 2020-12-28  136.486053
# 2020-12-29  134.668762
# 2020-12-30  133.520477
# 2020-12-31  132.492020

# %%
# Using another free place to get stock data
ticker = 'TSLA'
df3 = pdr.get_data_stooq(ticker, start, end)
df3.head()
# Out:
#               Open    High       Low   Close    Volume
# Date
# 2020-12-31  699.99  718.72  691.1200  705.67  49649928
# 2020-12-30  672.00  696.60  668.3603  694.78  42846021
# 2020-12-29  661.00  669.90  655.0000  665.99  22910811
# 2020-12-28  674.51  681.40  660.8000  663.69  32278561
# 2020-12-24  642.99  666.09  641.0000  661.77  22865568

# %%
import matplotlib as plt

# %%
df3.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Getting nasdaq symbols
nas_sym = pdr.get_nasdaq_symbols()

# %%
nas_sym
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Listed Funds Trust AAF First Priority CLO Bond...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC.U            True  Ares Acquisition Corporation Units, each consi...
# ...               ...                                                ...
# ZXYZ.A           True                 Nasdaq Symbology Test Common Stock
# ZXZZT            True                                  NASDAQ TEST STOCK
# ZYME             True                       Zymeworks Inc. Common Shares
# ZYNE             True       Zynerba Pharmaceuticals, Inc. - Common Stock
# ZYXI             True                         Zynex, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# ...

# %%
# Looking just at tesla
nas_sym.loc['TSLA']
# Out:
# Nasdaq Traded                              True
# Security Name       Tesla, Inc.  - Common Stock
# Listing Exchange                              Q
# Market Category                               Q
# ETF                                       False
# Round Lot Size                              100
# Test Issue                                False
# Financial Status                              N
# CQS Symbol                                  NaN
# NASDAQ Symbol                              TSLA
# NextShares                                False
# Name: TSLA, dtype: object

# %% [markdown]
# # Moving Averages
# ![image.png](attachment:image.png)

# %%
ticker = 'AAPL'
start = dt.datetime(2019,1,1)
df = pdr.get_data_yahoo(ticker,start)

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2019-01-02  39.712502  38.557499  38.722500  39.480000  148158800.0  38.505024
# 2019-01-03  36.430000  35.500000  35.994999  35.547501  365248800.0  34.669640
# 2019-01-04  37.137501  35.950001  36.132500  37.064999  234428400.0  36.149662
# 2019-01-07  37.207500  36.474998  37.174999  36.982498  219111200.0  36.069202
# 2019-01-08  37.955002  37.130001  37.389999  37.687500  164101200.0  36.756794

# %%
df['Close'].rolling(2).mean().head()
# Out:
# Date
# 2019-01-02          NaN
# 2019-01-03    37.513750
# 2019-01-04    36.306250
# 2019-01-07    37.023748
# 2019-01-08    37.334999
# Name: Close, dtype: float64

# %%
# Showing the 2 day rolling average calculated from above
(39.480000+35.547501)/2
# Out:
# 37.5137505

# %%
# Weekly rolling average
df['Close'].rolling(7).mean().head(7)
# Out:
# Date
# 2019-01-02          NaN
# 2019-01-03          NaN
# 2019-01-04          NaN
# 2019-01-07          NaN
# 2019-01-08          NaN
# 2019-01-09          NaN
# 2019-01-10    37.648571
# Name: Close, dtype: float64

# %%
df['weekly_moving_average'] = df['Close'].rolling(7).mean()

# %%
df.head(7)
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2019-01-02  39.712502  38.557499  38.722500  39.480000  148158800.0
# 2019-01-03  36.430000  35.500000  35.994999  35.547501  365248800.0
# 2019-01-04  37.137501  35.950001  36.132500  37.064999  234428400.0
# 2019-01-07  37.207500  36.474998  37.174999  36.982498  219111200.0
# 2019-01-08  37.955002  37.130001  37.389999  37.687500  164101200.0
# 2019-01-09  38.632500  37.407501  37.822498  38.327499  180396400.0
# 2019-01-10  38.492500  37.715000  38.125000  38.450001  143122800.0
#
#             Adj Close  weekly_moving_average
# Date
# 2019-01-02  38.505024                    NaN
# 2019-01-03  34.669640                    NaN
# 2019-01-04  36.149662                    NaN
# 2019-01-07  36.069202                    NaN
# 2019-01-08  36.756794                    NaN
# 2019-01-09  37.380985                    NaN
# 2019-01-10  37.500465              37.648571

# %%
df[['Close','weekly_moving_average']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 2020 weekly moving average plot
df[['Close','weekly_moving_average']].loc['2020-01-01':].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Close'].rolling(50).mean()
df['Close'].rolling(200).mean()
# Out:
# Date
# 2019-01-02           NaN
# 2019-01-03           NaN
# 2019-01-04           NaN
# 2019-01-07           NaN
# 2019-01-08           NaN
#                  ...
# 2021-02-17    111.043687
# 2021-02-18    111.325787
# 2021-02-19    111.603187
# 2021-02-22    111.857400
# 2021-02-23    112.093400
# Name: Close, Length: 540, dtype: float64

# %%
df['50_moving_average'] = df['Close'].rolling(50).mean()
df['200_moving_average'] = df['Close'].rolling(200).mean()

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2019-01-02  39.712502  38.557499  38.722500  39.480000  148158800.0
# 2019-01-03  36.430000  35.500000  35.994999  35.547501  365248800.0
# 2019-01-04  37.137501  35.950001  36.132500  37.064999  234428400.0
# 2019-01-07  37.207500  36.474998  37.174999  36.982498  219111200.0
# 2019-01-08  37.955002  37.130001  37.389999  37.687500  164101200.0
#
#             Adj Close  weekly_moving_average  50_moving_average  \
# Date
# 2019-01-02  38.505024                    NaN                NaN
# 2019-01-03  34.669640                    NaN                NaN
# 2019-01-04  36.149662                    NaN                NaN
# 2019-01-07  36.069202                    NaN                NaN
# 2019-01-08  36.756794                    NaN                NaN
#
#             200_moving_average
# Date
# 2019-01-02                 NaN
# 2019-01-03                 NaN
# 2019-01-04                 NaN
# ...

# %%
# 2020 weekly, 50 and 200 day moving average
df[['Close','weekly_moving_average','50_moving_average','200_moving_average']].loc['2020-01-01':].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import pandas as pd

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2019-01-02  39.712502  38.557499  38.722500  39.480000  148158800.0
# 2019-01-03  36.430000  35.500000  35.994999  35.547501  365248800.0
# 2019-01-04  37.137501  35.950001  36.132500  37.064999  234428400.0
# 2019-01-07  37.207500  36.474998  37.174999  36.982498  219111200.0
# 2019-01-08  37.955002  37.130001  37.389999  37.687500  164101200.0
#
#             Adj Close  weekly_moving_average  50_moving_average  \
# Date
# 2019-01-02  38.505024                    NaN                NaN
# 2019-01-03  34.669640                    NaN                NaN
# 2019-01-04  36.149662                    NaN                NaN
# 2019-01-07  36.069202                    NaN                NaN
# 2019-01-08  36.756794                    NaN                NaN
#
#             200_moving_average
# Date
# 2019-01-02                 NaN
# 2019-01-03                 NaN
# 2019-01-04                 NaN
# ...

# %%
df = df.loc['2020-01-01':]

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0
#
#             Adj Close  weekly_moving_average  50_moving_average  \
# Date
# 2020-01-02  74.333511              72.624999           66.57730
# 2020-01-03  73.610840              73.104642           66.86465
# 2020-01-06  74.197395              73.659284           67.14775
# 2020-01-07  73.848442              73.962142           67.42180
# 2020-01-08  75.036385              74.440357           67.70485
#
#             200_moving_average
# Date
# 2020-01-02           54.935412
# 2020-01-03           55.072000
# 2020-01-06           55.202887
# ...

# %%
#This will reverse the dates to show the most recent date
#df = df.iloc[::-1]

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0
#
#             Adj Close  weekly_moving_average  50_moving_average  \
# Date
# 2020-01-02  74.333511              72.624999           66.57730
# 2020-01-03  73.610840              73.104642           66.86465
# 2020-01-06  74.197395              73.659284           67.14775
# 2020-01-07  73.848442              73.962142           67.42180
# 2020-01-08  75.036385              74.440357           67.70485
#
#             200_moving_average
# Date
# 2020-01-02           54.935412
# 2020-01-03           55.072000
# 2020-01-06           55.202887
# ...

# %% [markdown]
# # Creating an excel of apple stock using the data from pandas data reader

# %%
writer = pd.ExcelWriter('AAPL.xlsx',
                       engine='xlsxwriter',
                       date_format = 'yyyy-mm-dd',
                       datetime_format = 'yyyy-mm-dd')
sheet_name = 'Moving Average'
df[['Close', 'weekly_moving_average', '50_moving_average']].to_excel(writer, sheet_name = sheet_name)

worksheet = writer.sheets[sheet_name]
workbook = writer.book

# Create a format for a green cell
green_cell = workbook.add_format({
    'bg_color': '#C6EFCE',
    'font_color': '#006100'
})

# Create a format for a red cell
red_cell = workbook.add_format({
    'bg_color': '#FFC7CE',                            
    'font_color': '#9C0006'
})


# Set column width of Date
worksheet.set_column(0, 0, 15)


for col in range(1, 4):
    # Create a conditional formatted of type formula
    worksheet.conditional_format(1, col, len(df), col, {
        'type': 'formula',                                    
        'criteria': '=C2>=D2',
        'format': green_cell
    })

    # Create a conditional formatted of type formula
    worksheet.conditional_format(1, col, len(df), col, {
        'type': 'formula',                                    
        'criteria': '=C2<D2',
        'format': red_cell
    })

# Create a new chart object.
chart1 = workbook.add_chart({'type': 'line'})

# Add a series to the chart.
chart1.add_series({
        'name': "Weekly_Moving_Avg",
        'categories': [sheet_name, 1, 0, len(df), 0],
        'values': [sheet_name, 1, 2, len(df), 2],
})

# Create a new chart object.
chart2 = workbook.add_chart({'type': 'line'})

# Add a series to the chart.
chart2.add_series({
        'name': '50_Day_Moving_Avg',
        'categories': [sheet_name, 1, 0, len(df), 0],
        'values': [sheet_name, 1, 3, len(df), 3],
})

# Combine and insert title, axis names
chart1.combine(chart2)
chart1.set_title({'name': sheet_name + " " + ticker})
chart1.set_x_axis({'name': 'Date'})
chart1.set_y_axis({'name': 'Price'})

# Insert the chart into the worksheet.
worksheet.insert_chart('F2', chart1)

writer.close()

# %% [markdown]
# # Calculating simple
# - Pct change
# - Log returns
# - Standard deviation (Volatility)
# - Rolling
#     - Simple Moving Avarage
#     - Exponential Moving Average

# %% [markdown]
# ### Standard deviation
#
# - $\sigma_{p} = \sigma_{daily}\times \sqrt{p}$
# - $\sigma_{annually} = \sigma_{daily}\times \sqrt{252}$
#
#     *(252 trading days per year)*

# %%
ticker = 'AAPL'
start = dt.datetime(2020,1,1)
df = pdr.get_data_yahoo(ticker,start)

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  74.333511
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.610840
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  74.197395
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.848442
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  75.036385

# %%
# Creating the percentage change
df['pct_chg'] = df['Close'].pct_change()

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0
#
#             Adj Close   pct_chg
# Date
# 2020-01-02  74.333511       NaN
# 2020-01-03  73.610840 -0.009722
# 2020-01-06  74.197395  0.007968
# 2020-01-07  73.848442 -0.004703
# 2020-01-08  75.036385  0.016086

# %%
# Confirming the percentage change from the 3rd to the 2nd
(74.357498 - 75.087502)/75.087502
# Out:
# -0.009722044022718906

# %%
#Importing numpy to use the log function
import numpy as np

# %%
# .shift take the previous days number and shift it down 1, look at example below
df['log_returns'] = np.log(df['Close']/df['Close'].shift())

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0
#
#             Adj Close   pct_chg  log_returns
# Date
# 2020-01-02  74.333511       NaN          NaN
# 2020-01-03  73.610840 -0.009722    -0.009770
# 2020-01-06  74.197395  0.007968     0.007937
# 2020-01-07  73.848442 -0.004703    -0.004714
# 2020-01-08  75.036385  0.016086     0.015958

# %%
df['Close']/df['Close'].shift()
#Numeric representation of what is happening above 3rd close/2nd close
#74.357498/75.087502
# Out:
# Date
# 2020-01-02         NaN
# 2020-01-03    0.990278
# 2020-01-06    1.007968
# 2020-01-07    0.995297
# 2020-01-08    1.016086
#                 ...
# 2021-02-17    0.982356
# 2021-02-18    0.991364
# 2021-02-19    1.001233
# 2021-02-22    0.970201
# 2021-02-23    0.977381
# Name: Close, Length: 288, dtype: float64

# %%
# Shows the previous days close on the next day. You can shift with any amount of days you want
df['Close'].shift()
# Out:
# Date
# 2020-01-02           NaN
# 2020-01-03     75.087502
# 2020-01-06     74.357498
# 2020-01-07     74.949997
# 2020-01-08     74.597504
#                  ...
# 2021-02-17    133.190002
# 2021-02-18    130.839996
# 2021-02-19    129.710007
# 2021-02-22    129.869995
# 2021-02-23    126.000000
# Name: Close, Length: 288, dtype: float64

# %%
df['log_returns'].std()
# Out:
# 0.0284644140308853

# %% [markdown]
# # Volatility
# $\sigma_{annually} = \sigma_{daily}\times \sqrt{252}$

# %%
volatility = df['log_returns'].std()*252**.5
volatility
# Out:
# 0.45185856444540073

# %%
str_vol = str(round(volatility,5)*100)
str_vol
# Out:
# '45.186'

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
fig, ax = plt.subplots()
df['log_returns'].hist(ax=ax, bins=50, alpha=.6, color='r')
ax.set_xlabel('Log Return')
ax.set_ylabel('Frequency of Log Return')
ax.set_title('AAPL Volatility: ' + str_vol +'%')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'AAPL Volatility: 45.186%')

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0
#
#             Adj Close   pct_chg  log_returns
# Date
# 2020-01-02  74.333511       NaN          NaN
# 2020-01-03  73.610840 -0.009722    -0.009770
# 2020-01-06  74.197395  0.007968     0.007937
# 2020-01-07  73.848442 -0.004703    -0.004714
# 2020-01-08  75.036385  0.016086     0.015958

# %%
75.087502+74.357498
# Out:
# 149.445

# %%
# Looking at rolling sum. Is the sum of the previous date and current date. Example above
df['Close'].rolling(2).sum()
# Out:
# Date
# 2020-01-02           NaN
# 2020-01-03    149.445000
# 2020-01-06    149.307495
# 2020-01-07    149.547501
# 2020-01-08    150.395004
#                  ...
# 2021-02-17    264.029999
# 2021-02-18    260.550003
# 2021-02-19    259.580002
# 2021-02-22    255.869995
# 2021-02-23    249.150002
# Name: Close, Length: 288, dtype: float64

# %%
df['Close'].rolling(10).mean()
# Out:
# Date
# 2020-01-02           NaN
# 2020-01-03           NaN
# 2020-01-06           NaN
# 2020-01-07           NaN
# 2020-01-08           NaN
#                  ...
# 2021-02-17    135.092999
# 2021-02-18    134.670000
# 2021-02-19    133.917999
# 2021-02-22    132.842000
# 2021-02-23    131.466000
# Name: Close, Length: 288, dtype: float64

# %%
# Adding 10 day moving average
df['10_day_MA'] = df['Close'].rolling(10).mean()

# %%
df.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-02-17  132.220001  129.470001  131.250000  130.839996   97918500.0
# 2021-02-18  130.000000  127.410004  129.199997  129.710007   96648100.0
# 2021-02-19  130.710007  128.800003  130.240005  129.869995   87525900.0
# 2021-02-22  129.720001  125.599998  128.009995  126.000000  103607600.0
# 2021-02-23  124.120003  118.389999  123.760002  123.150002   73349014.0
#
#              Adj Close   pct_chg  log_returns   10_day_MA
# Date
# 2021-02-17  130.839996 -0.017644    -0.017802  135.092999
# 2021-02-18  129.710007 -0.008636    -0.008674  134.670000
# 2021-02-19  129.869995  0.001233     0.001233  133.917999
# 2021-02-22  126.000000 -0.029799    -0.030252  132.842000
# 2021-02-23  123.150002 -0.022619    -0.022879  131.466000

# %%
# 50 day moving average
df['50_day_MA'] = df['Close'].rolling(50).mean()

# %%
# Exponential moving average
# Adjust - Divide by decaying adjustment factor in beginning periods to account for imbalance in relative
# weightings (viewing EWMA as a moving average) it is default true so want to change to false.
df['10Day_exp_MA'] = df['Close'].ewm(span = 10, adjust =False).mean()

# %%
df.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-02-17  132.220001  129.470001  131.250000  130.839996   97918500.0
# 2021-02-18  130.000000  127.410004  129.199997  129.710007   96648100.0
# 2021-02-19  130.710007  128.800003  130.240005  129.869995   87525900.0
# 2021-02-22  129.720001  125.599998  128.009995  126.000000  103607600.0
# 2021-02-23  124.120003  118.389999  123.760002  123.150002   73349014.0
#
#              Adj Close   pct_chg  log_returns   10_day_MA  50_day_MA  \
# Date
# 2021-02-17  130.839996 -0.017644    -0.017802  135.092999   131.5882
# 2021-02-18  129.710007 -0.008636    -0.008674  134.670000   131.7374
# 2021-02-19  129.869995  0.001233     0.001233  133.917999   131.8598
# 2021-02-22  126.000000 -0.029799    -0.030252  132.842000   131.8922
# 2021-02-23  123.150002 -0.022619    -0.022879  131.466000   131.9196
#
#             10Day_exp_MA
# Date
# 2021-02-17    134.455718
# 2021-02-18    133.592862
# ...

# %%
# 10 day MA and 10 day exponential MA
fig, ax = plt.subplots()
df[['10_day_MA', '10Day_exp_MA']].plot(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots()
df[['10_day_MA', '10Day_exp_MA']].loc['2020-12-01':].plot(ax=ax)
df[['Close']].loc['2020-12-01':].plot(ax=ax, alpha=.5)
ax.set_xlabel('Date')
ax.set_ylabel('Price')
ax.set_title('AAPL 10 Day Moving/Exponential Average & Closing Price')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'AAPL 10 Day Moving/Exponential Average & Closing Price')

# %% [markdown]
# # MACD
# - MACD is lagging indicator when trading on the crossover
# - Calculation (12-26-9 MACD (default))
# - MACD = 12 periods EMA - 26 period EMA
# - Signal line 9 - Period EMA of MACD

# %% [markdown]
# # Scholastic oscillator
# - Lagging indicator
# - Calculations:
#     - 14 High: Maximum of last 14 days of trading
#     - 14 Low: Low of the last 14 days of trading
#     - %K: (Last Close - 14 Low) * 100 / (14 high - 14 low)
#     - %D: Simple Moving Average of %K

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  \
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0
#
#             Adj Close   pct_chg  log_returns  10_day_MA  50_day_MA  \
# Date
# 2020-01-02  74.333511       NaN          NaN        NaN        NaN
# 2020-01-03  73.610840 -0.009722    -0.009770        NaN        NaN
# 2020-01-06  74.197395  0.007968     0.007937        NaN        NaN
# 2020-01-07  73.848442 -0.004703    -0.004714        NaN        NaN
# 2020-01-08  75.036385  0.016086     0.015958        NaN        NaN
#
#             10Day_exp_MA
# Date
# 2020-01-02     75.087502
# 2020-01-03     74.954774
# 2020-01-06     74.953905
# 2020-01-07     74.889105
# ...

# %%
# Exponential Moving average of 12 days
exp1 = df['Close'].ewm(span =12, adjust=False).mean()

# %%
# Exponential Moving average of 26 days
exp2 = df['Close'].ewm(span =26, adjust=False).mean()

# %%
df['MACD'] = exp1 - exp2

# %%
df['signal_line'] = df['MACD'].ewm(span =9, adjust=False).mean()

# %%
df.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-02-17  132.220001  129.470001  131.250000  130.839996   97918500.0
# 2021-02-18  130.000000  127.410004  129.199997  129.710007   96648100.0
# 2021-02-19  130.710007  128.800003  130.240005  129.869995   87525900.0
# 2021-02-22  129.720001  125.599998  128.009995  126.000000  103607600.0
# 2021-02-23  124.120003  118.389999  123.760002  123.150002   73349014.0
#
#              Adj Close   pct_chg  log_returns   10_day_MA  50_day_MA  \
# Date
# 2021-02-17  130.839996 -0.017644    -0.017802  135.092999   131.5882
# 2021-02-18  129.710007 -0.008636    -0.008674  134.670000   131.7374
# 2021-02-19  129.869995  0.001233     0.001233  133.917999   131.8598
# 2021-02-22  126.000000 -0.029799    -0.030252  132.842000   131.8922
# 2021-02-23  123.150002 -0.022619    -0.022879  131.466000   131.9196
#
#             10Day_exp_MA      MACD  signal_line
# Date
# ...

# %%
fig, ax = plt.subplots()
df[['MACD','signal_line']].plot(ax=ax)
df['Close'].plot(ax=ax, alpha =.25)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots()
df[['MACD','signal_line']].plot(ax=ax)
df[['Close']].plot(ax=ax, alpha =.25, secondary_y=True)
ax.set_title("MACD, Signal Line, and Close Values")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'MACD, Signal Line, and Close Values')

# %%
# 14 day high rolling average
high14 = df['High'].rolling(14).max()
# 14 day low rolling average
low14 = df['Low'].rolling(14).min()

# %%
# %K: (Last Close - 14 Low) * 100 / (14 high - 14 low)
df['%k'] = (df['Close'] - low14)* 100/ (high14 - low14)

# %%
 # %D: Simple Moving Average of %K of 3 days
df['%d'] = df['%k'].rolling(3).mean()

# %%
df.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-02-17  132.220001  129.470001  131.250000  130.839996   97918500.0
# 2021-02-18  130.000000  127.410004  129.199997  129.710007   96648100.0
# 2021-02-19  130.710007  128.800003  130.240005  129.869995   87525900.0
# 2021-02-22  129.720001  125.599998  128.009995  126.000000  103607600.0
# 2021-02-23  124.120003  118.389999  123.760002  123.150002   73349014.0
#
#              Adj Close   pct_chg  log_returns   10_day_MA  50_day_MA  \
# Date
# 2021-02-17  130.839996 -0.017644    -0.017802  135.092999   131.5882
# 2021-02-18  129.710007 -0.008636    -0.008674  134.670000   131.7374
# 2021-02-19  129.869995  0.001233     0.001233  133.917999   131.8598
# 2021-02-22  126.000000 -0.029799    -0.030252  132.842000   131.8922
# 2021-02-23  123.150002 -0.022619    -0.022879  131.466000   131.9196
#
#             10Day_exp_MA      MACD  signal_line         %k         %d
# Date
# ...

# %%
fig, ax = plt.subplots()
df[['%k','%d']].plot(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
# Going to make chart with smaller date range
fig, ax = plt.subplots()
df[['%k','%d']].loc['2020-12-01':].plot(ax=ax)
ax.axhline(80, c='r', alpha = .4)
ax.axhline(20, c='r', alpha = .4)
df[['Close']].loc['2020-12-01':].plot(ax=ax, alpha=.4, secondary_y=True)
ax.set_title('Scholastic Oscillator')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Scholastic Oscillator')
